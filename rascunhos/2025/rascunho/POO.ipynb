// %% [markdown]
// ## Teste java no Visual Studio Code notebook jupyter

// %%
IO.print("Alô, mundo!");
// Out:
// Compile error:
// |    IO.print("Alô, mundo!");
// java.io.IO is a preview API and is disabled by default.
//   (use --enable-preview to enable preview APIs)
